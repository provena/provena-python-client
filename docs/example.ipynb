# %% [markdown]
# # Provena Client Library Workflow Guide and Example.

# %% [markdown]
# This notebook contains guidance and examples on how to use the Provena Client Library with common Provena operations (create, fetch, model run lodge etc.)
#
# The client library is an user friendly interface to interact with the various API's of Provena (Registry, Prov, Datastore, etc.) through code and is currently compatiable with the Python programming language.
#
# To find further information or explore other Provena operations of the client library: https://provena.github.io/provena-python-client/

# %% [markdown]
# ### Client Configuration and Initialisation

# %%
# Import initial modules needed.
from provenaclient import ProvenaClient, Config
from provenaclient.auth import DeviceFlow
from provenaclient.auth.implementations import OfflineFlow
from pprint import pprint

# %% [markdown]
# Instantiate the client library by providing the domain your Provena instance is hosted on and the name of your Keycloak realm.

# %%
# Provena config - replace with your Provena instance endpoints
client_config = Config(
    domain="dev.rrap-is.com",
    realm_name="rrap"
)

offline_mode = False

if offline_mode:
    load_dotenv()
    offline_token=os.getenv('PROVENA_API_TOKEN')
    assert offline_token, "Offline token must be present in .env file e.g. PROVENA_API_TOKEN=1234."
    print(f"Offline mode activated and token found in .env file.")

if not offline_mode:
    auth = DeviceFlow(config=client_config,
                    client_id="client-tools")
else:
    auth = OfflineFlow(config=client_config, client_id="automated-access", offline_token=offline_token)


# Instantiate the client.
client = ProvenaClient(config=client_config, auth=auth)
# Out:
# 2024-07-31 23:45:43,213 - auth-logger - ERROR - The token used for refresh is invalid or has potentially expired. Something went wrong during token refresh. Status code: 400.
# Verification URL: https://auth.dev.rrap-is.com/auth/realms/rrap/device?user_code=MYIC-VLRE
# User Code: MYIC-VLRE

# %% [markdown]
# ## Querying Datastore API.

# %% [markdown]
# We will take a look at querying and interacting with the Datastore API exploring common operations of fetching dataset, minting dataset and fetching all datasets in various formats (paginated, all).

# %%
dataset = await client.datastore.fetch_dataset(id = "10378.1/1908974")

print(dataset) # Fetched dataset pythonic object.
print()
print("Dataset Query Details:", dataset.status.details) # Accessing fetched dataset query details
print()
print("Dataset Display Name:", dataset.item.display_name) # Accessing fetched dataset name
# Out:
# status=Status(success=True, details="Successfully fetched data for handle '10378.1/1908974'") item=ItemDataset(display_name='TEst', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1877551', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='TEst', description='TEst', access_info=AccessInfo(reposited=False, uri='http://google.com', description='test'), publisher_id='10378.1/1877551', created_date=CreatedDate(relevant=True, value=datetime.date(2024, 6, 5)), published_date=PublishedDate(relevant=True, value=datetime.date(2024, 6, 21)), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1908974/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1908974/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri='http://google.com', history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1718251565, reason='Initial record creation', username='ross', item=DatasetDomainInfo(display_name='TEst', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1877551', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='TEst', description='TEst', access_info=AccessInfo(reposited=False, uri='http://google.com', description='test'), publisher_id='10378.1/1877551', created_date=CreatedDate(relevant=True, value=datetime.date(2024, 6, 5)), published_date=PublishedDate(relevant=True, value=datetime.date(2024, 6, 21)), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1908974/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1908974/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri='http://google.com', user_metadata=None))], id='10378.1/1908974', owner_username='ross', created_timestamp=1718251564, updated_timestamp=1718251565, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='cc078e51-6468-46c7-86bc-21c45741a11f', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None)) roles=['metadata-read', 'metadata-write', 'admin', 'dataset-data-r ...
#
# Dataset Query Details: Successfully fetched data for handle '10378.1/1908974'
#
# Dataset Display Name: TEst

# %%
from ProvenaInterfaces.RegistryModels import *

dataset_to_create = CollectionFormat(
        associations=CollectionFormatAssociations(
        organisation_id="10378.1/1893860",
        data_custodian_id="10378.1/1893843",
        point_of_contact= None
        ),
        approvals=CollectionFormatApprovals(
            ethics_registration = DatasetEthicsRegistrationCheck(relevant=False, obtained=False),
            ethics_access=DatasetEthicsAccessCheck(relevant= False, obtained= False),
            indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained= False),
            export_controls=ExportControls(relevant=False, obtained=False)
        ),
        dataset_info=CollectionFormatDatasetInfo(
            name="Parth testing",
            description="testing dataset",
            access_info=AccessInfo(reposited=True, uri=None, description=None),
            publisher_id="10378.1/1893860",
            published_date=date.today(),
            license = "https://www.google.com", #type:ignore
            created_date=date.today(),
            purpose= None,
            rights_holder=None,
            usage_limitations=None,
            preferred_citation=None,
            formats = None,
            keywords= None,
            user_metadata= None,
            version = None
        )
    )

created_dataset = await client.datastore.mint_dataset(dataset_mint_info=dataset_to_create)

print("Created Dataset handle is:", created_dataset.handle)
print("Created Dataset reqeuest details:", created_dataset.status.details)

# %%
from ProvenaInterfaces.RegistryAPI import *

# Sort criteria to receive datasets.
sort_criteria = NoFilterSubtypeListRequest(
            sort_by=SortOptions(sort_type=SortType.DISPLAY_NAME, ascending=False, begins_with=None), 
            pagination_key=None, 
            page_size=10
        )


list_datasets = await client.datastore.list_datasets(list_dataset_request=sort_criteria)

for i in list_datasets:
    print(i)
# Out:
# ('status', Status(success=True, details='Successfully listed items.'))
# ('items', [ItemDataset(display_name='WaveEcologyModel Output Grapes', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875957', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='WaveEcologyModel Output Grapes', description='An opus of oceanic orchestration, where data motifs crescendo into a symphony of ecological enlightenment, harmonizing the cacophony of coral complexity into a serenade of predictive precision.', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875957', created_date=datetime.date(2024, 4, 24), published_date=datetime.date(2024, 4, 24), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1879549/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1879549/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1713929936, reason='Initial record creation', username='cai.bonilla@fake.com', item=DatasetDomainInfo(display_name='WaveEcologyModel Output Grapes', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875957', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='WaveEcologyModel Output Grapes', description='An opus of oceanic orchestration, where data motifs crescendo into a symphony of ecological enlightenment, harmonizing the cacophony of coral complexity into a serenade of predictive precision.', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875957', created_date=datetime.date(2024, 4, 24), published_date=datetime.date(2024, 4, 24), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1879549/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1879549/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1879549', owner_username='cai.bonilla@fake.com', created_timestamp=1713929935, updated_timestamp=1713929936, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='8517ee3a-d6c9-48f ...
# ('seed_items', [])
# ('unparsable_items', [])
# ('total_item_count', 10)
# ('complete_item_count', 10)
# ('seed_item_count', 0)
# ('unparsable_item_count', 0)
# ('not_authorised_count', 0)
# ('pagination_key', {'id': '10378.1/1876004', 'display_name': 'SeabedSimulator Input Dataset', 'item_subtype': 'DATASET'})

# %%
# Getting all datasets in datastore with specified sort criteria.
all_datasets = await client.datastore.list_all_datasets(sort_criteria=sort_criteria)
pprint(all_datasets)
# Out:
# [ItemDataset(display_name='TEst', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1877551', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='TEst', description='TEst', access_info=AccessInfo(reposited=False, uri='http://google.com', description='test'), publisher_id='10378.1/1877551', created_date=datetime.date(2024, 6, 5), published_date=datetime.date(2024, 6, 21), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1908974/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1908974/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri='http://google.com', history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1718251565, reason='Initial record creation', username='ross', item=DatasetDomainInfo(display_name='TEst', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1877551', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='TEst', description='TEst', access_info=AccessInfo(reposited=False, uri='http://google.com', description='test'), publisher_id='10378.1/1877551', created_date=datetime.date(2024, 6, 5), published_date=datetime.date(2024, 6, 21), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1908974/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1908974/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri='http://google.com', user_metadata=None))], id='10378.1/1908974', owner_username='ross', created_timestamp=1718251564, updated_timestamp=1718251565, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='cc078e51-6468-46c7-86bc-21c45741a11f', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None)),
#  ItemDataset(display_name='Parth testing', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 6, 6), published_date=datetime.date(2024, 6, 6), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=CollectionFormatSpatialInfo(coverage=None, resolution=None, extent='SRID=4326;POINT(-44.3 60.1)'), temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1904964/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1904964/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=5, timestamp=1718239752, reason='s', username='ross', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 6, 6), published_date=datetime.date(2024, 6, 6), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=CollectionFormatSpatialInfo(coverage=None, resolution=None, extent='SRID=4326;POINT(-44.3 60.1)'), temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1904964/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1904964/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None)), HistoryEntry[DatasetDomainInfo](id=4, timestamp=1718239743, reason='ss', username='ross', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description ...
#  ItemDataset(display_name='Parth testing', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 6, 6), published_date=datetime.date(2024, 6, 6), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1904961/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1904961/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1717633076, reason='Initial record creation', username='parth', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 6, 6), published_date=datetime.date(2024, 6, 6), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1904961/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1904961/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1904961', owner_username='parth', created_timestamp=1717633075, updated_timestamp=1717633076, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='3481da92-4972-455c-beab-0120b2c6d859', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None)),
#  ItemDataset(display_name='Parth testing', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 6, 6), published_date=datetime.date(2024, 6, 6), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1904960/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1904960/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1717633044, reason='Initial record creation', username='parth', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 6, 6), published_date=datetime.date(2024, 6, 6), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1904960/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1904960/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1904960', owner_username='parth', created_timestamp=1717633043, updated_timestamp=1717633044, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='a2ecc16a-5ce7-4278-9346-6443396dacc3', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None)),
#  ItemDataset(display_name='Parth testing', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 6, 6), published_date=datetime.date(2024, 6, 6), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1904958/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1904958/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1717632590, reason='Initial record creation', username='parth', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 6, 6), published_date=datetime.date(2024, 6, 6), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1904958/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1904958/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1904958', owner_username='parth', created_timestamp=1717632589, updated_timestamp=1717632590, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='c3af8e89-c2a6-4803-8ba6-05ebf62cddd4', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None)),
#  ItemDataset(display_name='Parth testing', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 6, 6), published_date=datetime.date(2024, 6, 6), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1904956/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1904956/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1717632508, reason='Initial record creation', username='parth', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 6, 6), published_date=datetime.date(2024, 6, 6), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1904956/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1904956/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1904956', owner_username='parth', created_timestamp=1717632507, updated_timestamp=1717632508, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='79339bd0-647e-420f-aace-3e2c1e143918', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None)),
#  ItemDataset(display_name='Parth testing', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 28), published_date=datetime.date(2024, 5, 28), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1900164/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1900164/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1716862545, reason='Initial record creation', username='peter', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 28), published_date=datetime.date(2024, 5, 28), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1900164/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1900164/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1900164', owner_username='peter', created_timestamp=1716862544, updated_timestamp=1716862545, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='c6de971f-4a1f-428e-9926-032fb5d7ca31', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None)),
#  ItemDataset(display_name='Parth testing', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 28), published_date=datetime.date(2024, 5, 28), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1900161/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1900161/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1716862239, reason='Initial record creation', username='peter', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 28), published_date=datetime.date(2024, 5, 28), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1900161/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1900161/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1900161', owner_username='peter', created_timestamp=1716862238, updated_timestamp=1716862239, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='498230cd-907d-4697-bf03-3bdca0ebd0bd', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None)),
#  ItemDataset(display_name='Parth testing', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 28), published_date=datetime.date(2024, 5, 28), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1900159/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1900159/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1716862228, reason='Initial record creation', username='peter', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 28), published_date=datetime.date(2024, 5, 28), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1900159/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1900159/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1900159', owner_username='peter', created_timestamp=1716862227, updated_timestamp=1716862228, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='eeab3b48-cbb2-4e73-9eea-8a0525507035', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None)),
#  ItemDataset(display_name='Parth testing', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 28), published_date=datetime.date(2024, 5, 28), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1900157/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1900157/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1716862087, reason='Initial record creation', username='peter', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 28), published_date=datetime.date(2024, 5, 28), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1900157/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1900157/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1900157', owner_username='peter', created_timestamp=1716862086, updated_timestamp=1716862087, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='42bd8dd4-08b1-4107-b150-93ebf2f5c972', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None)),
#  ItemDataset(display_name='Parth testing', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 24), published_date=datetime.date(2024, 5, 24), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1898010/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1898010/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1716512680, reason='Initial record creation', username='parth', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 24), published_date=datetime.date(2024, 5, 24), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1898010/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1898010/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1898010', owner_username='parth', created_timestamp=1716512679, updated_timestamp=1716512680, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='f717fa0c-464a-4acc-ae26-f8db3651dc08', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None)),
#  ItemDataset(display_name='Parth testing', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 24), published_date=datetime.date(2024, 5, 24), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1898009/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1898009/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1716512651, reason='Initial record creation', username='parth', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 24), published_date=datetime.date(2024, 5, 24), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1898009/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1898009/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1898009', owner_username='parth', created_timestamp=1716512650, updated_timestamp=1716512651, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='86b78daa-016a-4300-8ba3-83171e90390f', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None)),
#  ItemDataset(display_name='Parth testing', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 24), published_date=datetime.date(2024, 5, 24), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1897994/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1897994/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1716512219, reason='Initial record creation', username='parth', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 24), published_date=datetime.date(2024, 5, 24), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1897994/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1897994/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1897994', owner_username='parth', created_timestamp=1716512218, updated_timestamp=1716512219, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='a8c69f20-680d-41de-b85b-40f11afb45d2', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None)),
# ...
#  ItemDataset(display_name='SeabedSimulator Input Dataset', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875955', data_custodian_id='10378.1/1875939', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='SeabedSimulator Input Dataset', description="The SedimentGeochemAtlas, a geospatial database encompassing geochemical profiles of marine sediments sampled from continental shelves, abyssal plains, and submarine canyons across global ocean basins. Enhanced with remote sensing data on seafloor topography and bathymetric features, this dataset serves as the cornerstone for SeabedSimulator's agent-based modeling algorithms, facilitating the simulation of sediment transport dynamics, benthic colonization patterns, and geomorphic morphodynamics at unprecedented spatial resolutions.", access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875955', created_date=datetime.date(2024, 4, 18), published_date=datetime.date(2024, 4, 18), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1876004/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1876004/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1713402266, reason='Initial record creation', username='peter', item=DatasetDomainInfo(display_name='SeabedSimulator Input Dataset', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875955', data_custodian_id='10378.1/1875939', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='SeabedSimulator Input Dataset', description="The SedimentGeochemAtlas, a geospatial database encompassing geochemical profiles of marine sediments sampled from continental shelves, abyssal plains, and submarine canyons across global ocean basins. Enhanced with remote sensing data on seafloor topography and bathymetric features, this dataset serves as the cornerstone for SeabedSimulator's agent-based modeling algorithms, facilitating the simulation of sediment transport dynamics, benthic colonization patterns, and geomorphic morphodynamics at unprecedented spatial resolutions.", access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875955', created_date=datetime.date(2024, 4, 18), published_date=datetime.date(2024, 4, 18), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-st ...
#  ItemDataset(display_name='TidalEcoModel Input Dataset', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875954', data_custodian_id='10378.1/1875939', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='TidalEcoModel Input Dataset', description="The HydrodynamicTideNet dataset, a comprehensive compilation of spatiotemporal tidal current measurements obtained from satellite altimetry, oceanographic buoys, and in-situ sensors deployed across tidal estuaries and coastal embayments worldwide. Augmented with ancillary data on sediment grain size distribution and benthic habitat classification, this dataset serves as the primary input for TidalEcoModel's Lagrangian fluid dynamics simulations, elucidating the intricate feedbacks between tidal hydrodynamics and ecological processes.", access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875954', created_date=datetime.date(2024, 4, 18), published_date=datetime.date(2024, 4, 18), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1876001/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1876001/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1713402211, reason='Initial record creation', username='peter', item=DatasetDomainInfo(display_name='TidalEcoModel Input Dataset', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875954', data_custodian_id='10378.1/1875939', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='TidalEcoModel Input Dataset', description="The HydrodynamicTideNet dataset, a comprehensive compilation of spatiotemporal tidal current measurements obtained from satellite altimetry, oceanographic buoys, and in-situ sensors deployed across tidal estuaries and coastal embayments worldwide. Augmented with ancillary data on sediment grain size distribution and benthic habitat classification, this dataset serves as the primary input for TidalEcoModel's Lagrangian fluid dynamics simulations, elucidating the intricate feedbacks between tidal hydrodynamics and ecological processes.", access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875954', created_date=datetime.date(2024, 4, 18), published_date=datetime.date(2024, 4, 18), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storag ...
#  ItemDataset(display_name='CoralReefSim Input Dataset', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id='10378.1/1875939', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Input Dataset', description="The CoralGenomeX dataset, comprising high-throughput genomic sequences of coral species across diverse reef habitats, meticulously annotated with metadata on environmental variables such as temperature, pH, and nutrient availability. This multidimensional dataset serves as the foundation for CoralReefSim's stochastic cellular automata algorithms, enabling the simulation of coral genotype-phenotype interactions and the emergent dynamics of reef community structure under varying climatic scenarios.", access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2024, 4, 18), published_date=datetime.date(2024, 4, 18), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1876000/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1876000/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1713402151, reason='Initial record creation', username='peter', item=DatasetDomainInfo(display_name='CoralReefSim Input Dataset', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id='10378.1/1875939', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Input Dataset', description="The CoralGenomeX dataset, comprising high-throughput genomic sequences of coral species across diverse reef habitats, meticulously annotated with metadata on environmental variables such as temperature, pH, and nutrient availability. This multidimensional dataset serves as the foundation for CoralReefSim's stochastic cellular automata algorithms, enabling the simulation of coral genotype-phenotype interactions and the emergent dynamics of reef community structure under varying climatic scenarios.", access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2024, 4, 18), published_date=datetime.date(2024, 4, 18), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1876000/', s3_uri='s3://rest ...

# %%
# Get a total number of datasets (specified limit) with provided sort criteria. 
async for dataset in client.datastore.for_all_datasets(list_dataset_request=sort_criteria, total_limit=30):
    pprint(dataset)
# Out:
# ItemDataset(display_name='Parth testing', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 28), published_date=datetime.date(2024, 5, 28), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1900164/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1900164/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1716862545, reason='Initial record creation', username='peter', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 28), published_date=datetime.date(2024, 5, 28), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1900164/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1900164/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1900164', owner_username='peter', created_timestamp=1716862544, updated_timestamp=1716862545, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='c6de971f-4a1f-428e-9926-032fb5d7ca31', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None))
# ItemDataset(display_name='Parth testing', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 6, 6), published_date=datetime.date(2024, 6, 6), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1904961/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1904961/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1717633076, reason='Initial record creation', username='parth', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 6, 6), published_date=datetime.date(2024, 6, 6), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1904961/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1904961/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1904961', owner_username='parth', created_timestamp=1717633075, updated_timestamp=1717633076, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='3481da92-4972-455c-beab-0120b2c6d859', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None))
# ItemDataset(display_name='Parth testing', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 24), published_date=datetime.date(2024, 5, 24), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1898009/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1898009/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1716512651, reason='Initial record creation', username='parth', item=DatasetDomainInfo(display_name='Parth testing', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1893860', data_custodian_id='10378.1/1893843', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Parth testing', description='testing dataset', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1893860', created_date=datetime.date(2024, 5, 24), published_date=datetime.date(2024, 5, 24), license=AnyHttpUrl('https://www.google.com', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1898009/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1898009/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1898009', owner_username='parth', created_timestamp=1716512650, updated_timestamp=1716512651, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='86b78daa-016a-4300-8ba3-83171e90390f', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None))
# ItemDataset(display_name='MarineBioSim Input Dataset', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875956', data_custodian_id='10378.1/1875939', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='MarineBioSim Input Dataset', description="The MetaMicrobiomeOmics repository, an extensive compendium of metagenomic, metatranscriptomic, and metabolomic datasets derived from microbial communities inhabiting diverse marine ecosystems, ranging from coral reefs to deep-sea hydrothermal vents. Integrated with environmental metadata on temperature gradients, nutrient fluxes, and anthropogenic stressors, this dataset serves as the fundamental input for MarineBioSim's artificial intelligence algorithms, enabling the prediction of microbial community dynamics, functional gene expression profiles, and biogeochemical cycling pathways within marine environments.\n", access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875956', created_date=datetime.date(2024, 4, 18), published_date=datetime.date(2024, 4, 18), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1876006/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1876006/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1713402314, reason='Initial record creation', username='peter', item=DatasetDomainInfo(display_name='MarineBioSim Input Dataset', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875956', data_custodian_id='10378.1/1875939', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='MarineBioSim Input Dataset', description="The MetaMicrobiomeOmics repository, an extensive compendium of metagenomic, metatranscriptomic, and metabolomic datasets derived from microbial communities inhabiting diverse marine ecosystems, ranging from coral reefs to deep-sea hydrothermal vents. Integrated with environmental metadata on temperature gradients, nutrient fluxes, and anthropogenic stressors, this dataset serves as the fundamental input for MarineBioSim's artificial intelligence algorithms, enabling the prediction of microbial community dynamics, functional gene expression profiles, and biogeochemical cycling pathways within marine environments.\n", access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875956', created_date=datetime.date(2024, 4, 18), published_date=datetime.date(2024, 4, 18), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None,  ...
# ItemDataset(display_name='CoralReefSim Output blueberry', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id='10378.1/1879518', point_of_contact='itsyaboii@fake.com'), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Output blueberry', description='CoralReefSim Output blueberry coral outputs or something like that.', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2022, 1, 24), published_date=datetime.date(2024, 4, 12), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1879541/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1879541/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1713929815, reason='Initial record creation', username='steven.boyer@fake.com', item=DatasetDomainInfo(display_name='CoralReefSim Output blueberry', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id='10378.1/1879518', point_of_contact='itsyaboii@fake.com'), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Output blueberry', description='CoralReefSim Output blueberry coral outputs or something like that.', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2022, 1, 24), published_date=datetime.date(2024, 4, 12), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1879541/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1879541/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1879541', owner_username='steven.boyer@fake.com', created_timestamp=1713929814, updated_timestamp=1713929815, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='2a531dea-47c3-4573-b181-ac227fc4d544', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None))
# ItemDataset(display_name='CoralReefSim Output Watermelon', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Output Watermelon', description='Behold the cosmic tableau of coral cosmology, where data points orbit like celestial bodies in the vast expanse of ecological space-time, forging constellations of predictive prowess amidst the abyssal depths.', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2024, 4, 23), published_date=datetime.date(2024, 4, 23), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1879061/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1879061/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1713855329, reason='Initial record creation', username='sammie.lester@fake.com', item=DatasetDomainInfo(display_name='CoralReefSim Output Watermelon', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Output Watermelon', description='Behold the cosmic tableau of coral cosmology, where data points orbit like celestial bodies in the vast expanse of ecological space-time, forging constellations of predictive prowess amidst the abyssal depths.', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2024, 4, 23), published_date=datetime.date(2024, 4, 23), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1879061/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1879061/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1879061', owner_username='sammie.lester@fake.com', created_timestamp=1713855328, updated_timestamp=1713855329, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workf ...
# ItemDataset(display_name='CoralReefSim Output Pineapple', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Output Pineapple', description='Behold the cosmic tableau of coral cosmology, where data points orbit like celestial bodies in the vast expanse of ecological space-time, forging constellations of predictive prowess amidst the abyssal depths.', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2024, 4, 24), published_date=datetime.date(2024, 4, 24), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1879539/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1879539/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1713929806, reason='Initial record creation', username='lucas.torres@fake.com', item=DatasetDomainInfo(display_name='CoralReefSim Output Pineapple', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Output Pineapple', description='Behold the cosmic tableau of coral cosmology, where data points orbit like celestial bodies in the vast expanse of ecological space-time, forging constellations of predictive prowess amidst the abyssal depths.', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2024, 4, 24), published_date=datetime.date(2024, 4, 24), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1879539/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1879539/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1879539', owner_username='lucas.torres@fake.com', created_timestamp=1713929805, updated_timestamp=1713929806, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id ...
# ItemDataset(display_name='CoralReefSim Output Pineapple', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=True, obtained=True), ethics_access=DatasetEthicsAccessCheck(relevant=True, obtained=True), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Output Pineapple', description='As we traverse the digital coral labyrinth, each data point becomes a lantern illuminating the cryptic corridors of ecological enlightenment, guiding us towards the esoteric sanctum of reef resilience.', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2024, 4, 23), published_date=datetime.date(2024, 4, 23), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1879063/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1879063/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1713855573, reason='Initial record creation', username='jarrett.wilkerson@fake.com', item=DatasetDomainInfo(display_name='CoralReefSim Output Pineapple', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=True, obtained=True), ethics_access=DatasetEthicsAccessCheck(relevant=True, obtained=True), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Output Pineapple', description='As we traverse the digital coral labyrinth, each data point becomes a lantern illuminating the cryptic corridors of ecological enlightenment, guiding us towards the esoteric sanctum of reef resilience.', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2024, 4, 23), published_date=datetime.date(2024, 4, 23), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1879063/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1879063/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1879063', owner_username='jarrett.wilkerson@fake.com', created_timestamp=1713855572, updated_timestamp=1713855573, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='e77ad369-247 ...
# ItemDataset(display_name='CoralReefSim Output Passionfruit', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id='10378.1/1879523', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Output Passionfruit', description='test', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2024, 4, 24), published_date=datetime.date(2024, 4, 24), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1879542/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1879542/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1713929818, reason='Initial record creation', username='susan.weeks@fake.com', item=DatasetDomainInfo(display_name='CoralReefSim Output Passionfruit', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id='10378.1/1879523', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Output Passionfruit', description='test', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2024, 4, 24), published_date=datetime.date(2024, 4, 24), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1879542/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1879542/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1879542', owner_username='susan.weeks@fake.com', created_timestamp=1713929817, updated_timestamp=1713929818, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='63c09865-b45f-4fe8-ac29-4a7e3698c287', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None))
# ItemDataset(display_name='CoralReefSim Output Blackberry', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id='10378.1/1879524', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Output Blackberry', description='A palimpsest of ecological narratives inscribed upon the digital scroll, where each datum serves as a quill pen to etch the memoirs of coral conviviality, revealing the epistemological underpinnings of reef resilience.', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2024, 4, 24), published_date=datetime.date(2024, 4, 24), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1879556/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1879556/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1713929985, reason='Initial record creation', username='lucie.barnett@fake.com', item=DatasetDomainInfo(display_name='CoralReefSim Output Blackberry', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id='10378.1/1879524', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Output Blackberry', description='A palimpsest of ecological narratives inscribed upon the digital scroll, where each datum serves as a quill pen to etch the memoirs of coral conviviality, revealing the epistemological underpinnings of reef resilience.', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2024, 4, 24), published_date=datetime.date(2024, 4, 24), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1879556/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1879556/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1879556', owner_username='lucie.barnett@fake.com', created_timestamp=1713929985, updated_timestamp=1713929985, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workfl ...
# ItemDataset(display_name='CoralReefSim Input Dataset', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id='10378.1/1875939', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Input Dataset', description="The CoralGenomeX dataset, comprising high-throughput genomic sequences of coral species across diverse reef habitats, meticulously annotated with metadata on environmental variables such as temperature, pH, and nutrient availability. This multidimensional dataset serves as the foundation for CoralReefSim's stochastic cellular automata algorithms, enabling the simulation of coral genotype-phenotype interactions and the emergent dynamics of reef community structure under varying climatic scenarios.", access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2024, 4, 18), published_date=datetime.date(2024, 4, 18), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1876000/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1876000/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1713402151, reason='Initial record creation', username='peter', item=DatasetDomainInfo(display_name='CoralReefSim Input Dataset', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1875953', data_custodian_id='10378.1/1875939', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CoralReefSim Input Dataset', description="The CoralGenomeX dataset, comprising high-throughput genomic sequences of coral species across diverse reef habitats, meticulously annotated with metadata on environmental variables such as temperature, pH, and nutrient availability. This multidimensional dataset serves as the foundation for CoralReefSim's stochastic cellular automata algorithms, enabling the simulation of coral genotype-phenotype interactions and the emergent dynamics of reef community structure under varying climatic scenarios.", access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1875953', created_date=datetime.date(2024, 4, 18), published_date=datetime.date(2024, 4, 18), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1876000/', s3_uri='s3://resto ...
# ItemDataset(display_name='Coral results 2021-02-30', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1877551', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Coral results 2021-02-30', description='Results of counterfactual model run', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1877551', created_date=datetime.date(2021, 12, 25), published_date=datetime.date(2021, 12, 25), license=AnyHttpUrl('https://creativecommons.org/licenses/by/4.0/', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1877566/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1877566/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1713506028, reason='Initial record creation', username='ross', item=DatasetDomainInfo(display_name='Coral results 2021-02-30', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1877551', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Coral results 2021-02-30', description='Results of counterfactual model run', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1877551', created_date=datetime.date(2021, 12, 25), published_date=datetime.date(2021, 12, 25), license=AnyHttpUrl('https://creativecommons.org/licenses/by/4.0/', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1877566/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1877566/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1877566', owner_username='ross', created_timestamp=1713506028, updated_timestamp=1713506028, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='f94a4bae-cbfd-439a-ab09-3c22d09b3643', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None))
# ...
# ItemDataset(display_name='Coral results 2021-02-30', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1882197', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Coral results 2021-02-30', description='Results of counterfactual model run', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1882197', created_date=datetime.date(2021, 12, 25), published_date=datetime.date(2021, 12, 25), license=AnyHttpUrl('https://creativecommons.org/licenses/by/4.0/', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=['keyword1', 'keyword2'], user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1882198/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1882198/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1714355648, reason='New version of existing item (id=10378.1/1882198).', username='integration-test-read-write-bot', item=DatasetDomainInfo(display_name='Coral results 2021-02-30', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1882197', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Coral results 2021-02-30', description='Results of counterfactual model run', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1882197', created_date=datetime.date(2021, 12, 25), published_date=datetime.date(2021, 12, 25), license=AnyHttpUrl('https://creativecommons.org/licenses/by/4.0/', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=['keyword1', 'keyword2'], user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1882198/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1882198/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1882200', owner_username='integration-test-read-write-bot', created_timestamp=1714355648, updated_timestamp=1714355648, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='687b7f8a-4c4f-480e-a017-13e593971014'), versioning_info=VersioningInfo(previous_version='10378.1/1882198', version=2, reason='Integration testing', next_version=None))
# ItemDataset(display_name='Coral results 2021-02-30', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1877551', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Coral results 2021-02-30', description='Results of counterfactual model run', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1877551', created_date=datetime.date(2021, 12, 25), published_date=datetime.date(2021, 12, 25), license=AnyHttpUrl('https://creativecommons.org/licenses/by/4.0/', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1877568/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1877568/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1713506073, reason='Initial record creation', username='ross', item=DatasetDomainInfo(display_name='Coral results 2021-02-30', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1877551', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Coral results 2021-02-30', description='Results of counterfactual model run', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1877551', created_date=datetime.date(2021, 12, 25), published_date=datetime.date(2021, 12, 25), license=AnyHttpUrl('https://creativecommons.org/licenses/by/4.0/', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1877568/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1877568/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1877568', owner_username='ross', created_timestamp=1713506072, updated_timestamp=1713506073, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='aa7ee0e0-f304-431a-993b-ce4a1b3dfddd', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None))
# ItemDataset(display_name='CScape testing data', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1877551', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CScape testing data', description='CScape testing data', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1877551', created_date=datetime.date(2024, 5, 21), published_date=datetime.date(2024, 5, 21), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1896123/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1896123/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1716272348, reason='Initial record creation', username='peter', item=DatasetDomainInfo(display_name='CScape testing data', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1877551', data_custodian_id=None, point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='CScape testing data', description='CScape testing data', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1877551', created_date=datetime.date(2024, 5, 21), published_date=datetime.date(2024, 5, 21), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1896123/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1896123/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1896123', owner_username='peter', created_timestamp=1716272347, updated_timestamp=1716272348, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='fb4fa93e-8364-40d7-9b65-6526cf5bd0c8', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None))
# ItemDataset(display_name='Airflow Example Dataset', user_metadata=None, collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1877551', data_custodian_id='10378.1/1876218', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Airflow Example Dataset', description='Airflow Example Dataset to house a simple parameter', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1877551', created_date=datetime.date(2024, 5, 3), published_date=datetime.date(2024, 5, 3), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1885378/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1885378/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, history=[HistoryEntry[DatasetDomainInfo](id=0, timestamp=1714697756, reason='Initial record creation', username='ross', item=DatasetDomainInfo(display_name='Airflow Example Dataset', collection_format=CollectionFormat(associations=CollectionFormatAssociations(organisation_id='10378.1/1877551', data_custodian_id='10378.1/1876218', point_of_contact=None), approvals=CollectionFormatApprovals(ethics_registration=DatasetEthicsRegistrationCheck(relevant=False, obtained=False), ethics_access=DatasetEthicsAccessCheck(relevant=False, obtained=False), indigenous_knowledge=IndigenousKnowledgeCheck(relevant=False, obtained=False), export_controls=ExportControls(relevant=False, obtained=False)), dataset_info=CollectionFormatDatasetInfo(name='Airflow Example Dataset', description='Airflow Example Dataset to house a simple parameter', access_info=AccessInfo(reposited=True, uri=None, description=None), publisher_id='10378.1/1877551', created_date=datetime.date(2024, 5, 3), published_date=datetime.date(2024, 5, 3), license=AnyHttpUrl('https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', ), purpose=None, rights_holder=None, usage_limitations=None, preferred_citation=None, spatial_info=None, temporal_info=None, formats=None, keywords=None, user_metadata=None, version=None)), s3=S3Location(bucket_name='restored-dev-dev-rrap-storage-bucket-11102022-11102022', path='datasets/10378-1-1885378/', s3_uri='s3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1885378/'), release_history=[], release_status=<ReleasedStatus.NOT_RELEASED: 'NOT_RELEASED'>, release_approver=None, release_timestamp=None, access_info_uri=None, user_metadata=None))], id='10378.1/1885378', owner_username='ross', created_timestamp=1714697754, updated_timestamp=1714697756, item_category=<ItemCategory.ENTITY: 'ENTITY'>, item_subtype=<ItemSubType.DATASET: 'DATASET'>, record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'>, workflow_links=WorkflowLinks(create_activity_workflow_id='a7ed4707-8cc2-4014-9564-9a48c8247cad', version_activity_workflow_id=None), versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version=None))

# %% [markdown]
# ## Querying Provenance API.

# %% [markdown]
# #### We will now take a look at exploring some of the common operations of the PROV-API with existing and valid entities.

# %% [markdown]
# Exploring Lineage

# %%
# Upstream

print("Exploring upstream query")

upstream_result = await client.prov_api.explore_upstream(starting_id="10378.1/1904964")
pprint(upstream_result)
print()
pprint(upstream_result.graph.get('nodes'))

print()

print("Exploring downstream query")

downstream_result = await client.prov_api.explore_downstream(starting_id="10378.1/1904961")
pprint(downstream_result)
print()
pprint(downstream_result.graph.get('nodes'))
# Out:
# Exploring upstream query
# LineageResponse(status=Status(success=True, details='Made lineage query (with depth 3) to neo4j backend.'), record_count=5, graph={'directed': True, 'multigraph': False, 'graph': {}, 'nodes': [{'item_category': 'ENTITY', 'item_subtype': 'DATASET', 'id': '10378.1/1904964'}, {'item_category': 'ACTIVITY', 'item_subtype': 'CREATE', 'id': '10378.1/1904975'}, {'item_category': 'AGENT', 'item_subtype': 'PERSON', 'id': '10378.1/1893843'}, {'item_category': 'ENTITY', 'item_subtype': 'DATASET_TEMPLATE', 'id': '10378.1/1905250'}, {'item_category': 'ACTIVITY', 'item_subtype': 'CREATE', 'id': '10378.1/1905252'}], 'links': [{'type': 'wasGeneratedBy', 'source': '10378.1/1904964', 'target': '10378.1/1904975'}, {'type': 'wasAttributedTo', 'source': '10378.1/1904964', 'target': '10378.1/1893843'}, {'type': 'wasInfluencedBy', 'source': '10378.1/1904964', 'target': '10378.1/1905250'}, {'type': 'wasAssociatedWith', 'source': '10378.1/1904975', 'target': '10378.1/1893843'}, {'type': 'wasGeneratedBy', 'source': '10378.1/1905250', 'target': '10378.1/1905252'}, {'type': 'wasAttributedTo', 'source': '10378.1/1905250', 'target': '10378.1/1893843'}, {'type': 'wasAssociatedWith', 'source': '10378.1/1905252', 'target': '10378.1/1893843'}]})
#
# [{'id': '10378.1/1904964',
#   'item_category': 'ENTITY',
#   'item_subtype': 'DATASET'},
#  {'id': '10378.1/1904975',
#   'item_category': 'ACTIVITY',
#   'item_subtype': 'CREATE'},
#  {'id': '10378.1/1893843', 'item_category': 'AGENT', 'item_subtype': 'PERSON'},
#  {'id': '10378.1/1905250',
#   'item_category': 'ENTITY',
#   'item_subtype': 'DATASET_TEMPLATE'},
#  {'id': '10378.1/1905252',
#   'item_category': 'ACTIVITY',
#   'item_subtype': 'CREATE'}]
#
# Exploring downstream query
# LineageResponse(status=Status(success=True, details='Made downstream query (with depth 3) to neo4j backend.'), record_count=8, graph={'directed': True, 'multigraph': False, 'graph': {}, 'nodes': [{'item_category': 'ACTIVITY', 'item_subtype': 'MODEL_RUN', 'id': '10378.1/1905254'}, {'item_category': 'ENTITY', 'item_subtype': 'DATASET', 'id': '10378.1/1904961'}, {'item_category': 'ACTIVITY', 'item_subtype': 'MODEL_RUN', 'id': '10378.1/1905265'}, {'item_category': 'ACTIVITY', 'item_subtype': 'MODEL_RUN', 'id': '10378.1/1905266'}, {'item_category': 'ACTIVITY', 'item_subtype': 'MODEL_RUN', 'id': '10378.1/1905267'}, {'item_category': 'ACTIVITY', 'item_subtype': 'MODEL_RUN', 'id': '10378.1/1905280'}, {'item_category': 'ACTIVITY', 'item_subtype': 'MODEL_RUN', 'id': '10378.1/1908496'}, {'item_category': 'ENTITY', 'item_subtype': 'DATASET', 'id': '10378.1/1900159'}], 'links': [{'type': 'used', 'source': '10378.1/1905254', 'target': '10378.1/1904961'}, {'type': 'wasGeneratedBy', 'source': '10378.1/1904961', 'target': '10378.1/1905254'}, {'type': 'wasGeneratedBy', 'source': '10378.1/1904961', 'target': '10378.1/1905265'}, {'type': 'wasGeneratedBy', 'source': '10378.1/1904961', 'target': '10378.1/1905266'}, {'type': 'wasGeneratedBy', 'source': '10378.1/1904961', 'target': '10378.1/1905267'}, {'type': 'used', 'source': '10378.1/1905265', 'target': '10378.1/1904961'}, {'type': 'used', 'source': '10378.1/1905266', 'target': '10378.1/1904961'}, {'type': 'used', 'source': '10378.1/1905267', 'target': '10378.1/1904961'}, {'type': 'used', 'source': '10378.1/1905280', 'target': '10378.1/1904961'}, {'type': 'used', 'source': '10378.1/1908496', 'target': '10378.1/1904961'}, {'type': 'wasGeneratedBy', 'source': '10378.1/1900159', 'target': '10378.1/1905280'}, {'type': 'wasGeneratedBy', 'source': '10378.1/1900159', 'target': '10378.1/1908496'}]})
#
# [{'id': '10378.1/1905254',
#   'item_category': 'ACTIVITY',
#   'item_subtype': 'MODEL_RUN'},
#  {'id': '10378.1/1904961',
#   'item_category': 'ENTITY',
#   'item_subtype': 'DATASET'},
#  {'id': '10378.1/1905265',
#   'item_category': 'ACTIVITY',
#   'item_subtype': 'MODEL_RUN'},
#  {'id': '10378.1/1905266',
#   'item_category': 'ACTIVITY',
#   'item_subtype': 'MODEL_RUN'},
#  {'id': '10378.1/1905267',
#   'item_category': 'ACTIVITY',
#   'item_subtype': 'MODEL_RUN'},
#  {'id': '10378.1/1905280',
#   'item_category': 'ACTIVITY',
#   'item_subtype': 'MODEL_RUN'},
#  {'id': '10378.1/1908496',
#   'item_category': 'ACTIVITY',
#   'item_subtype': 'MODEL_RUN'},
#  {'id': '10378.1/1900159',
#   'item_category': 'ENTITY',
#   'item_subtype': 'DATASET'}]

# %%
# Contributing and Effected Datasets

contributing_datasets = await client.prov_api.get_contributing_datasets(starting_id = "10378.1/1904964")
print("Contributing datasets " + "\n", contributing_datasets)

effected_datasets = await client.prov_api.get_effected_datasets(starting_id = "10378.1/1904964")
print("Effected datasets " + "\n", effected_datasets)
# Out:
# Contributing datasets
#  status=Status(success=True, details='Made upstream contribution query (with depth 3) to neo4j backend.') record_count=0 graph={'directed': True, 'multigraph': False, 'graph': {}, 'nodes': [], 'links': []}
# Effected datasets
#  status=Status(success=True, details='Made downstream effect query (with depth 3) to neo4j backend.') record_count=5 graph={'directed': True, 'multigraph': False, 'graph': {}, 'nodes': [{'item_category': 'ENTITY', 'item_subtype': 'DATASET', 'id': '10378.1/1904961'}, {'item_category': 'ACTIVITY', 'item_subtype': 'MODEL_RUN', 'id': '10378.1/1926259'}, {'item_category': 'ENTITY', 'item_subtype': 'DATASET', 'id': '10378.1/1904964'}, {'item_category': 'ACTIVITY', 'item_subtype': 'MODEL_RUN', 'id': '10378.1/1926270'}, {'item_category': 'ACTIVITY', 'item_subtype': 'MODEL_RUN', 'id': '10378.1/1926271'}], 'links': [{'type': 'wasGeneratedBy', 'source': '10378.1/1904961', 'target': '10378.1/1926259'}, {'type': 'wasGeneratedBy', 'source': '10378.1/1904961', 'target': '10378.1/1926270'}, {'type': 'wasGeneratedBy', 'source': '10378.1/1904961', 'target': '10378.1/1926271'}, {'type': 'used', 'source': '10378.1/1926259', 'target': '10378.1/1904964'}, {'type': 'used', 'source': '10378.1/1926270', 'target': '10378.1/1904964'}, {'type': 'used', 'source': '10378.1/1926271', 'target': '10378.1/1904964'}]}

# %% [markdown]
# Lodging Model Runs && Querying with Job-API

# %%
from ProvenaInterfaces.ProvenanceAPI import ModelRunRecord, TemplatedDataset, DatasetType, AssociationInfo
from ProvenaInterfaces.AsyncJobAPI import JobStatus

# Building the Model Run Payload.
model_run_payload = ModelRunRecord(
    workflow_template_id=config.workflow_configuration.workflow_template,
    model_version = None, 
    inputs = [
        TemplatedDataset(
            dataset_template_id=config.inputs.input_dataset_template, 
            dataset_id=config.inputs.input_dataset,
            dataset_type=DatasetType.DATA_STORE
        )
    ], 
    outputs=[
        TemplatedDataset(
            dataset_template_id=config.outputs.output_dataset_template, 
            dataset_id=config.outputs.output_dataset,
            dataset_type=DatasetType.DATA_STORE
        )
    ], 
    annotations=None,
    display_name="Notebook Model Run Testing",
    description="Standard Provena Model Run Example",
    study_id=None,
    associations=AssociationInfo(
        modeller_id=config.associations.person,
        requesting_organisation_id=config.associations.organisation
    ),
    start_time=0,
    end_time=1

)

# %%
# Registering Model Run
model_run_register_result = await client.prov_api.register_model_run(model_run_payload=model_run_payload)

# %%
# Check the response of the model run registration
print("Status of registration", model_run_register_result.status)
print("Job Session ID", model_run_register_result.session_id)


# Check the job to see if it's complete. We will do this by polling the job_api
job_result = await client.job_api.await_successful_job_completion(session_id=model_run_register_result.session_id)

while job_result.status != JobStatus.SUCCEEDED: # Keep polling on this cell till this turns to "SUCCEEDED"
    
    job_result = await client.job_api.await_successful_job_completion(session_id=model_run_register_result.session_id)
    pprint(job_result.result)
    pprint(job_result.job_type)


print()
print("Current job status:", job_result.status)
# Out:
# Status of registration success=True details='Job dispatched, monitor session ID using the job API to see progress.'
# Job Session ID a76fdebf-b70d-48c9-a54c-6e979161abfb

# %% [markdown]
# ## Querying Registry API.

# %% [markdown]
# We will take a look at creating various entities with different subtypes (org, model) and then fetching those newly created entities through the client library.

# %%
# Organisation 
org_domain_info = OrganisationDomainInfo(
    display_name="Test org",
    name="Test org",
    ror="http://example.org/test-org", #type:ignore
    user_metadata={
        "my custom": "annotation",
        "another custom": "annotation"
    }
)
created_organisation = await client.registry.organisation.create_item(create_item_request=org_domain_info)
print("Created Organisation", created_organisation)

# Model 
model_domain_info = ModelDomainInfo(
    display_name="Example model",
    name="Example model",
    description="This is a fake model",
    documentation_url="https://example_model.org", #type:ignore
    source_url="https://example_model.org", #type:ignore
    user_metadata={
        "my custom": "annotation",
        "another custom": "annotation"
    }
)
created_model = await client.registry.model.create_item(create_item_request=model_domain_info)
print("Created Model", created_model)


# Fetching items...
fetched_org = await client.registry.organisation.fetch(id = created_organisation.created_item.id)
print("Fetched Organisation", fetched_org)

fetched_model = await client.registry.model.fetch(id = created_model.created_item.id)
print("Fetched model", fetched_model)

# %% [markdown]
# We will take a look at listing all items present in registry based on their subtypes (Organisation, Model) for this example.

# %%
from ProvenaInterfaces.RegistryAPI import GeneralListRequest

general_list_request = GeneralListRequest(
    filter_by=None,
    sort_by=None,
    pagination_key=None
)

list_org = await client.registry.organisation.list_items(list_items_payload=general_list_request)

for item in list_org.items:
    print(item, "\n")
# Out:
# display_name='Test org' user_metadata={'another custom': 'annotation', 'my custom': 'annotation'} name='Test org' ror=AnyHttpUrl('http://example.org/test-org', ) history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1720676140, reason='Initial record creation', username='parth', item=OrganisationDomainInfo(display_name='Test org', name='Test org', ror=AnyHttpUrl('http://example.org/test-org', ), user_metadata={'another custom': 'annotation', 'my custom': 'annotation'}))] id='10378.1/1925648' owner_username='parth' created_timestamp=1720676140 updated_timestamp=1720676140 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='Test org' user_metadata={'another custom': 'annotation', 'my custom': 'annotation'} name='Test org' ror=AnyHttpUrl('http://example.org/test-org', ) history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1720675608, reason='Initial record creation', username='parth', item=OrganisationDomainInfo(display_name='Test org', name='Test org', ror=AnyHttpUrl('http://example.org/test-org', ), user_metadata={'another custom': 'annotation', 'my custom': 'annotation'}))] id='10378.1/1925626' owner_username='parth' created_timestamp=1720675608 updated_timestamp=1720675608 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='Test org' user_metadata={'another custom': 'annotation', 'my custom': 'annotation'} name='Test org' ror=AnyHttpUrl('http://example.org/test-org', ) history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1720675230, reason='Initial record creation', username='parth', item=OrganisationDomainInfo(display_name='Test org', name='Test org', ror=AnyHttpUrl('http://example.org/test-org', ), user_metadata={'another custom': 'annotation', 'my custom': 'annotation'}))] id='10378.1/1925605' owner_username='parth' created_timestamp=1720675230 updated_timestamp=1720675230 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='Test org' user_metadata={'another custom': 'annotation', 'my custom': 'annotation'} name='Test org' ror=AnyHttpUrl('http://example.org/test-org', ) history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1720674733, reason='Initial record creation', username='parth', item=OrganisationDomainInfo(display_name='Test org', name='Test org', ror=AnyHttpUrl('http://example.org/test-org', ), user_metadata={'another custom': 'annotation', 'my custom': 'annotation'}))] id='10378.1/1925585' owner_username='parth' created_timestamp=1720674733 updated_timestamp=1720674733 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='Test org' user_metadata={'another custom': 'annotation', 'my custom': 'annotation'} name='Test org' ror=AnyHttpUrl('http://example.org/test-org', ) history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1720674253, reason='Initial record creation', username='parth', item=OrganisationDomainInfo(display_name='Test org', name='Test org', ror=AnyHttpUrl('http://example.org/test-org', ), user_metadata={'another custom': 'annotation', 'my custom': 'annotation'}))] id='10378.1/1925561' owner_username='parth' created_timestamp=1720674253 updated_timestamp=1720674253 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='Test org' user_metadata={'another custom': 'annotation', 'my custom': 'annotation'} name='Test org' ror=AnyHttpUrl('http://example.org/test-org', ) history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1720662164, reason='Initial record creation', username='parth', item=OrganisationDomainInfo(display_name='Test org', name='Test org', ror=AnyHttpUrl('http://example.org/test-org', ), user_metadata={'another custom': 'annotation', 'my custom': 'annotation'}))] id='10378.1/1925285' owner_username='parth' created_timestamp=1720662164 updated_timestamp=1720662164 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='Test org' user_metadata={'another custom': 'annotation', 'my custom': 'annotation'} name='Test org' ror=AnyHttpUrl('http://example.org/test-org', ) history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1720662158, reason='Initial record creation', username='parth', item=OrganisationDomainInfo(display_name='Test org', name='Test org', ror=AnyHttpUrl('http://example.org/test-org', ), user_metadata={'another custom': 'annotation', 'my custom': 'annotation'}))] id='10378.1/1925284' owner_username='parth' created_timestamp=1720662158 updated_timestamp=1720662158 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='Test org' user_metadata={'another custom': 'annotation', 'my custom': 'annotation'} name='Test org' ror=AnyHttpUrl('http://example.org/test-org', ) history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1720594778, reason='Initial record creation', username='parth', item=OrganisationDomainInfo(display_name='Test org', name='Test org', ror=AnyHttpUrl('http://example.org/test-org', ), user_metadata={'another custom': 'annotation', 'my custom': 'annotation'}))] id='10378.1/1924769' owner_username='parth' created_timestamp=1720594778 updated_timestamp=1720594778 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='Test Org' user_metadata=None name='Test Org' ror=AnyHttpUrl('http://example.com', ) history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1720416483, reason='Initial record creation', username='ross', item=OrganisationDomainInfo(display_name='Test Org', name='Test Org', ror=AnyHttpUrl('http://example.com', ), user_metadata=None))] id='10378.1/1923351' owner_username='ross' created_timestamp=1720416483 updated_timestamp=1720416483 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='Test Org' user_metadata=None name='Test Org' ror=AnyHttpUrl('http://example.com', ) history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1720416467, reason='Initial record creation', username='ross', item=OrganisationDomainInfo(display_name='Test Org', name='Test Org', ror=AnyHttpUrl('http://example.com', ), user_metadata=None))] id='10378.1/1923350' owner_username='ross' created_timestamp=1720416467 updated_timestamp=1720416467 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='Parth-org' user_metadata=None name='Parth   Orrg' ror=None history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1715908122, reason='Initial record creation', username='parth', item=OrganisationDomainInfo(display_name='Parth-org', name='Parth   Orrg', ror=None, user_metadata=None))] id='10378.1/1893860' owner_username='parth' created_timestamp=1715908122 updated_timestamp=1715908122 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='CSIRO' user_metadata=None name='CSIRO' ror=AnyHttpUrl('https://ror.org/03qn8fb07', ) history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1713504011, reason='Initial record creation', username='ross', item=OrganisationDomainInfo(display_name='CSIRO', name='CSIRO', ror=AnyHttpUrl('https://ror.org/03qn8fb07', ), user_metadata=None))] id='10378.1/1877551' owner_username='ross' created_timestamp=1713504011 updated_timestamp=1713504011 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='Blue Horizon Institute' user_metadata=None name='Blue Horizon Institute' ror=None history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1713400949, reason='Initial record creation', username='peter', item=OrganisationDomainInfo(display_name='Blue Horizon Institute', name='Blue Horizon Institute', ror=None, user_metadata=None))] id='10378.1/1875957' owner_username='peter' created_timestamp=1713400949 updated_timestamp=1713400949 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='Seafloor Explorers Network' user_metadata=None name='Seafloor Explorers Network' ror=None history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1713400931, reason='Initial record creation', username='peter', item=OrganisationDomainInfo(display_name='Seafloor Explorers Network', name='Seafloor Explorers Network', ror=None, user_metadata=None))] id='10378.1/1875956' owner_username='peter' created_timestamp=1713400931 updated_timestamp=1713400931 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='Maritime Discovery Consortium' user_metadata=None name='Maritime Discovery Consortium' ror=None history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1713400916, reason='Initial record creation', username='peter', item=OrganisationDomainInfo(display_name='Maritime Discovery Consortium', name='Maritime Discovery Consortium', ror=None, user_metadata=None))] id='10378.1/1875955' owner_username='peter' created_timestamp=1713400916 updated_timestamp=1713400916 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='AquaVenture Research Institute' user_metadata=None name='AquaVenture Research Institute' ror=None history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1713400903, reason='Initial record creation', username='peter', item=OrganisationDomainInfo(display_name='AquaVenture Research Institute', name='AquaVenture Research Institute', ror=None, user_metadata=None))] id='10378.1/1875954' owner_username='peter' created_timestamp=1713400903 updated_timestamp=1713400903 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None
#
# display_name='Oceanic Insight Alliance' user_metadata=None name='Oceanic Insight Alliance' ror=None history=[HistoryEntry[OrganisationDomainInfo](id=0, timestamp=1713400887, reason='Initial record creation', username='peter', item=OrganisationDomainInfo(display_name='Oceanic Insight Alliance', name='Oceanic Insight Alliance', ror=None, user_metadata=None))] id='10378.1/1875953' owner_username='peter' created_timestamp=1713400887 updated_timestamp=1713400887 item_category=<ItemCategory.AGENT: 'AGENT'> item_subtype=<ItemSubType.ORGANISATION: 'ORGANISATION'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=None versioning_info=None

# %%
list_models = await client.registry.model.list_items(list_items_payload=general_list_request)

for item in list_models.items:
    print(item, "\n")
# Out:
# display_name='ADRIA (Test)' user_metadata={'git_release': '', 'git_branch': 'provena-update', 'git_hash': 'e1cba08dddafc9df47523676b43869beceb6c68f'} name='ADRIA (Test)' description='ADRIA (Test) for testing GitHub integration.' documentation_url=AnyHttpUrl('https://github.com/open-AIMS/ADRIA.jl', ) source_url=AnyHttpUrl('https://github.com/open-AIMS/ADRIA.jl', ) history=[HistoryEntry[ModelDomainInfo](id=1, timestamp=1721804016, reason='Updating metadata attributes to specify new git hash, branch and release if available.', username='adria-bot', item=ModelDomainInfo(display_name='ADRIA (Test)', name='ADRIA (Test)', description='ADRIA (Test) for testing GitHub integration.', documentation_url=AnyHttpUrl('https://github.com/open-AIMS/ADRIA.jl', ), source_url=AnyHttpUrl('https://github.com/open-AIMS/ADRIA.jl', ), user_metadata={'git_release': '', 'git_branch': 'provena-update', 'git_hash': 'e1cba08dddafc9df47523676b43869beceb6c68f'})), HistoryEntry[ModelDomainInfo](id=0, timestamp=1721804007, reason='New version of existing item (id=10378.1/1934449).', username='adria-bot', item=ModelDomainInfo(display_name='ADRIA (Test)', name='ADRIA (Test)', description='ADRIA (Test) for testing GitHub integration.', documentation_url=AnyHttpUrl('https://github.com/open-AIMS/ADRIA.jl', ), source_url=AnyHttpUrl('https://github.com/open-AIMS/ADRIA.jl', ), user_metadata=None))] id='10378.1/1934463' owner_username='adria-bot' created_timestamp=1721804007 updated_timestamp=1721804016 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='a1ca2892-a50e-49e7-8c75-88d88f31afaf') versioning_info=VersioningInfo(previous_version='10378.1/1934449', version=2, reason='New ADRIA code release on GitHub. Version Unknown.', next_version=None)
#
# display_name='Github Actions Test Model' user_metadata={'git_release': '', 'git_branch': 'main', 'git_hash': '0175e71573a8bd5455f29ac233c0fa083da79c02'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/provena/version-update-item-action', ) history=[HistoryEntry[ModelDomainInfo](id=1, timestamp=1721803870, reason='Updating git custom attributes, as well as source URL.', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/provena/version-update-item-action', ), user_metadata={'git_release': '', 'git_branch': 'main', 'git_hash': '0175e71573a8bd5455f29ac233c0fa083da79c02'})), HistoryEntry[ModelDomainInfo](id=0, timestamp=1721803862, reason='New version of existing item (id=10378.1/1932118).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/provena/version-update-item-action', ), user_metadata={'git_release': 'v0.1.3', 'git_branch': 'v0.1.3', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'}))] id='10378.1/1934461' owner_username='peter' created_timestamp=1721803862 updated_timestamp=1721803870 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='0954d3b8-78be-4f35-aa7d-6ab0ba25cb0d') versioning_info=VersioningInfo(previous_version='10378.1/1932118', version=18, reason='Testing GitHub Action which can version and update items', next_version=None)
#
# display_name='ADRIA (Test)' user_metadata=None name='ADRIA (Test)' description='ADRIA (Test) for testing GitHub integration.' documentation_url=AnyHttpUrl('https://github.com/open-AIMS/ADRIA.jl', ) source_url=AnyHttpUrl('https://github.com/open-AIMS/ADRIA.jl', ) history=[HistoryEntry[ModelDomainInfo](id=0, timestamp=1721802318, reason='Initial record creation', username='adria-bot', item=ModelDomainInfo(display_name='ADRIA (Test)', name='ADRIA (Test)', description='ADRIA (Test) for testing GitHub integration.', documentation_url=AnyHttpUrl('https://github.com/open-AIMS/ADRIA.jl', ), source_url=AnyHttpUrl('https://github.com/open-AIMS/ADRIA.jl', ), user_metadata=None))] id='10378.1/1934449' owner_username='adria-bot' created_timestamp=1721802318 updated_timestamp=1721802318 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id='38b91eef-f8a2-40f9-be76-2f8580577971', version_activity_workflow_id=None) versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version='10378.1/1934463')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'v0.1.3', 'git_branch': 'v0.1.3', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/provena/version-update-item-action', ) history=[HistoryEntry[ModelDomainInfo](id=1, timestamp=1721605309, reason='Updating git custom attributes, as well as source URL.', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/provena/version-update-item-action', ), user_metadata={'git_release': 'v0.1.3', 'git_branch': 'v0.1.3', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'})), HistoryEntry[ModelDomainInfo](id=0, timestamp=1721605300, reason='New version of existing item (id=10378.1/1932116).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/provena/version-update-item-action', ), user_metadata={'git_release': 'v0.1.3', 'git_branch': 'v0.1.3', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'}))] id='10378.1/1932118' owner_username='peter' created_timestamp=1721605300 updated_timestamp=1721605309 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='7659941a-2bac-4750-9576-faf50a592deb') versioning_info=VersioningInfo(previous_version='10378.1/1932116', version=17, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1934461')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'v0.1.3', 'git_branch': 'v0.1.3', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/provena/version-update-item-action', ) history=[HistoryEntry[ModelDomainInfo](id=1, timestamp=1721605241, reason='Updating git custom attributes, as well as source URL.', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/provena/version-update-item-action', ), user_metadata={'git_release': 'v0.1.3', 'git_branch': 'v0.1.3', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'})), HistoryEntry[ModelDomainInfo](id=0, timestamp=1721605232, reason='New version of existing item (id=10378.1/1932114).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/provena/version-update-item-action', ), user_metadata={'git_release': '', 'git_branch': 'main', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'}))] id='10378.1/1932116' owner_username='peter' created_timestamp=1721605232 updated_timestamp=1721605241 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='49577042-9d2b-4677-ae06-9afb061d326c') versioning_info=VersioningInfo(previous_version='10378.1/1932114', version=16, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1932118')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': '', 'git_branch': 'main', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/provena/version-update-item-action', ) history=[HistoryEntry[ModelDomainInfo](id=1, timestamp=1721605218, reason='Updating git custom attributes, as well as source URL.', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/provena/version-update-item-action', ), user_metadata={'git_release': '', 'git_branch': 'main', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'})), HistoryEntry[ModelDomainInfo](id=0, timestamp=1721605209, reason='New version of existing item (id=10378.1/1932112).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}))] id='10378.1/1932114' owner_username='peter' created_timestamp=1721605209 updated_timestamp=1721605218 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='41d4dc0d-0bf1-4153-879c-ba58dda44f51') versioning_info=VersioningInfo(previous_version='10378.1/1932112', version=15, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1932116')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) history=[HistoryEntry[ModelDomainInfo](id=1, timestamp=1721605111, reason='Updating git custom attributes, as well as source URL.', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'})), HistoryEntry[ModelDomainInfo](id=0, timestamp=1721605102, reason='New version of existing item (id=10378.1/1932110).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}))] id='10378.1/1932112' owner_username='peter' created_timestamp=1721605102 updated_timestamp=1721605111 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='b602fbdc-7aea-48ad-9ccc-a078c34f06dd') versioning_info=VersioningInfo(previous_version='10378.1/1932110', version=14, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1932114')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) history=[HistoryEntry[ModelDomainInfo](id=1, timestamp=1721605055, reason='Updating git custom attributes, as well as source URL.', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'})), HistoryEntry[ModelDomainInfo](id=0, timestamp=1721605043, reason='New version of existing item (id=10378.1/1932076).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}))] id='10378.1/1932110' owner_username='peter' created_timestamp=1721605043 updated_timestamp=1721605055 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='f72e6a00-4c37-4e8e-8827-16cc86c89ca5') versioning_info=VersioningInfo(previous_version='10378.1/1932076', version=13, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1932112')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) history=[HistoryEntry[ModelDomainInfo](id=1, timestamp=1721600649, reason='Updating git custom attributes, as well as source URL.', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'})), HistoryEntry[ModelDomainInfo](id=0, timestamp=1721600637, reason='New version of existing item (id=10378.1/1932074).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}))] id='10378.1/1932076' owner_username='peter' created_timestamp=1721600637 updated_timestamp=1721600649 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='4d004b2e-c97c-4146-8dd1-6b0b9b1ceb9a') versioning_info=VersioningInfo(previous_version='10378.1/1932074', version=12, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1932110')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) history=[HistoryEntry[ModelDomainInfo](id=1, timestamp=1721599919, reason='Updating git custom attributes, as well as source URL.', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'})), HistoryEntry[ModelDomainInfo](id=0, timestamp=1721599911, reason='New version of existing item (id=10378.1/1932072).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}))] id='10378.1/1932074' owner_username='peter' created_timestamp=1721599911 updated_timestamp=1721599919 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='f177ce7b-4571-4441-9aa3-4a9f91ed1166') versioning_info=VersioningInfo(previous_version='10378.1/1932072', version=11, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1932076')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) history=[HistoryEntry[ModelDomainInfo](id=0, timestamp=1721599780, reason='New version of existing item (id=10378.1/1932070).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}))] id='10378.1/1932072' owner_username='peter' created_timestamp=1721599780 updated_timestamp=1721599780 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='9ebb9748-cfd7-41f0-aecc-1d03094e656f') versioning_info=VersioningInfo(previous_version='10378.1/1932070', version=10, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1932074')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) history=[HistoryEntry[ModelDomainInfo](id=0, timestamp=1721599352, reason='New version of existing item (id=10378.1/1932068).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}))] id='10378.1/1932070' owner_username='peter' created_timestamp=1721599352 updated_timestamp=1721599352 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='d47482e2-bcb3-4006-b281-7d83a47a29a4') versioning_info=VersioningInfo(previous_version='10378.1/1932068', version=9, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1932072')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) history=[HistoryEntry[ModelDomainInfo](id=0, timestamp=1721599294, reason='New version of existing item (id=10378.1/1932057).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}))] id='10378.1/1932068' owner_username='peter' created_timestamp=1721599294 updated_timestamp=1721599294 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='48c24eba-684d-4f47-81ad-1399204bc4ff') versioning_info=VersioningInfo(previous_version='10378.1/1932057', version=8, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1932070')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) history=[HistoryEntry[ModelDomainInfo](id=0, timestamp=1721599206, reason='New version of existing item (id=10378.1/1932052).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}))] id='10378.1/1932057' owner_username='peter' created_timestamp=1721599206 updated_timestamp=1721599206 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='f6bedcfd-2241-411a-8d74-a84d53bf0aeb') versioning_info=VersioningInfo(previous_version='10378.1/1932052', version=7, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1932068')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) history=[HistoryEntry[ModelDomainInfo](id=0, timestamp=1721599132, reason='New version of existing item (id=10378.1/1925594).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}))] id='10378.1/1932052' owner_username='peter' created_timestamp=1721599132 updated_timestamp=1721599132 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='26e456fc-007d-49c5-be3e-ba79309fccf9') versioning_info=VersioningInfo(previous_version='10378.1/1925594', version=6, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1932057')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) history=[HistoryEntry[ModelDomainInfo](id=0, timestamp=1720675003, reason='New version of existing item (id=10378.1/1925574).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}))] id='10378.1/1925594' owner_username='peter' created_timestamp=1720675003 updated_timestamp=1720675003 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='86aeb03f-7b50-4009-8099-3879f09f9ba5') versioning_info=VersioningInfo(previous_version='10378.1/1925574', version=5, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1932052')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) history=[HistoryEntry[ModelDomainInfo](id=0, timestamp=1720674604, reason='New version of existing item (id=10378.1/1925572).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}))] id='10378.1/1925574' owner_username='peter' created_timestamp=1720674604 updated_timestamp=1720674604 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='7060e46b-14e5-47ca-99c2-e5fb20bbe3fb') versioning_info=VersioningInfo(previous_version='10378.1/1925572', version=4, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1925594')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) history=[HistoryEntry[ModelDomainInfo](id=0, timestamp=1720674505, reason='New version of existing item (id=10378.1/1925570).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}))] id='10378.1/1925572' owner_username='peter' created_timestamp=1720674505 updated_timestamp=1720674505 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='4797fd42-2d6b-4787-ad4f-cd550b08ebb3') versioning_info=VersioningInfo(previous_version='10378.1/1925570', version=3, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1925574')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) history=[HistoryEntry[ModelDomainInfo](id=0, timestamp=1720674385, reason='New version of existing item (id=10378.1/1925475).', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}))] id='10378.1/1925570' owner_username='peter' created_timestamp=1720674385 updated_timestamp=1720674385 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id=None, version_activity_workflow_id='ef9e0f11-0dd3-4998-b0b2-fd47617f7fa8') versioning_info=VersioningInfo(previous_version='10378.1/1925475', version=2, reason='Testing GitHub Action which can version and update items', next_version='10378.1/1925572')
#
# display_name='Github Actions Test Model' user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'} name='Github Actions Test Model' description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.' documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ) history=[HistoryEntry[ModelDomainInfo](id=1, timestamp=1720673959, reason='Adding starting git attributes', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata={'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'})), HistoryEntry[ModelDomainInfo](id=0, timestamp=1720673316, reason='Initial record creation', username='peter', item=ModelDomainInfo(display_name='Github Actions Test Model', name='Github Actions Test Model', description='Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', documentation_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), source_url=AnyHttpUrl('https://github.com/PeterBaker0/update-provena-model-action', ), user_metadata=None))] id='10378.1/1925475' owner_username='peter' created_timestamp=1720673316 updated_timestamp=1720673959 item_category=<ItemCategory.ENTITY: 'ENTITY'> item_subtype=<ItemSubType.MODEL: 'MODEL'> record_type=<RecordType.COMPLETE_ITEM: 'COMPLETE_ITEM'> workflow_links=WorkflowLinks(create_activity_workflow_id='3cc31e30-e199-4cc6-b0e3-1514bef1fb20', version_activity_workflow_id=None) versioning_info=VersioningInfo(previous_version=None, version=1, reason=None, next_version='10378.1/1925570')

# %% [markdown]
# General Registry Actions (Fetching without subtype, Listing All Registry Items and Count of all items in registry (client library special))

# %%
# Fetching without subtype. 
fetch_result = await client.registry.general_fetch_item(id = "10378.1/1876000")
for item in fetch_result.item: 
    print("Fetched item", item)
# Out:
# Fetched item s3
# Fetched item versioning_info
# Fetched item release_history
# Fetched item owner_username
# Fetched item workflow_links
# Fetched item updated_timestamp
# Fetched item release_status
# Fetched item item_category
# Fetched item display_name
# Fetched item collection_format
# Fetched item history
# Fetched item item_subtype
# Fetched item created_timestamp
# Fetched item id
# Fetched item universal_partition_key
# Fetched item record_type

# %%
# Listing all registry items. 
all_general_registry_items = await client.registry.list_general_registry_items(general_list_request=general_list_request)
for item in all_general_registry_items.items: 
    print(item)
# Out:
# {'owner_username': 'parth', 'prov_serialisation': '{"prefix": {"default": "http://hdl.handle.net/"}, "activity": {"10378.1/1935470": {"model_run/10378.1/1935470": true, "item_category": "ACTIVITY", "item_subtype": "MODEL_RUN"}}, "entity": {"10378.1/1904964": {"model_run/10378.1/1935470": true, "item_category": "ENTITY", "item_subtype": "DATASET"}, "10378.1/1904961": {"model_run/10378.1/1935470": true, "item_category": "ENTITY", "item_subtype": "DATASET"}, "10378.1/1905251": {"model_run/10378.1/1935470": true, "item_category": "ENTITY", "item_subtype": "MODEL_RUN_WORKFLOW_TEMPLATE", "prov:type": {"$": "prov:Collection", "type": "prov:QUALIFIED_NAME"}}, "10378.1/1905250": {"model_run/10378.1/1935470": true, "item_category": "ENTITY", "item_subtype": "DATASET_TEMPLATE"}, "10378.1/1926245": {"model_run/10378.1/1935470": true, "item_category": "ENTITY", "item_subtype": "DATASET_TEMPLATE"}, "10378.1/1924630": {"model_run/10378.1/1935470": true, "item_category": "ENTITY", "item_subtype": "MODEL"}}, "agent": {"10378.1/1893843": {"model_run/10378.1/1935470": true, "item_category": "AGENT", "item_subtype": "PERSON"}, "10378.1/1893860": {"model_run/10378.1/1935470": true, "item_category": "AGENT", "item_subtype": "ORGANISATION"}}, "used": {"_:id1": {"prov:activity": "10378.1/1935470", "prov:entity": "10378.1/1904964"}, "_:id3": {"prov:activity": "10378.1/1935470", "prov:entity": "10378.1/1924630"}, "_:id4": {"prov:activity": "10378.1/1935470", "prov:entity": "10378.1/1905251"}}, "wasGeneratedBy": {"_:id2": {"prov:entity": "10378.1/1904961", "prov:activity": "10378.1/1935470"}}, "wasAssociatedWith": {"_:id5": {"prov:activity": "10378.1/1935470", "prov:agent": "10378.1/1893843"}, "_:id6": {"prov:activity": "10378.1/1935470", "prov:agent": "10378.1/1893860"}}, "wasAttributedTo": {"_:id7": {"prov:entity": "10378.1/1904961", "prov:agent": "10378.1/1893843"}}, "hadMember": {"_:id8": {"prov:collection": "10378.1/1905251", "prov:entity": "10378.1/1905250"}, "_:id10": {"prov:collection": "10378.1/1905251", "prov:entity": "10378.1/1926245"}, "_:id12": {"prov:collection": "10378.1/1905251", "prov:entity": "10378.1/1924630"}}, "wasInfluencedBy": {"_:id9": {"prov:influencee": "10378.1/1904964", "prov:influencer": "10378.1/1905250"}, "_:id11": {"prov:influencee": "10378.1/1904961", "prov:influencer": "10378.1/1926245"}}}', 'updated_timestamp': 1721965135, 'item_category': 'ACTIVITY', 'display_name': 'Notebook Model Run Testing', 'history': [{'reason': 'Updating item to mark completion of provenance lodge.', 'item': {'display_name': 'Notebook Model Run Testing', 'record_status': 'LODGED', 'record': {'outputs': [{'dataset_template_id': '10378.1/1926245', 'dataset_type': 'DATA_STORE', 'dataset_id': '10378.1/1904961'}], 'associations': {'modeller_id': '10378.1/1893843', 'requesting_organisation_id': '10378.1/1893860'}, 'start_time': 0, 'inputs': [{'dataset_template_id': '10378.1/1905250', 'dataset_type': 'DATA_STORE', 'dataset_id': '10378.1/1904964'}], 'end_time': 1, 'description': 'Standard Provena Model Run Example', 'workflow_template_id': '10378.1/1905251', 'display_name': 'Notebook Model Run Testing'}, 'prov_serialisation': '{"prefix": {"default": "http://hdl.handle.net/"}, "activity": {"10378.1/1935470": {"model_run/10378.1/1935470": true, "item_category": "ACTIVITY", "item_subtype": "MODEL_RUN"}}, "entity": {"10378.1/1904964": {"model_run/10378.1/1935470": true, "item_category": "ENTITY", "item_subtype": "DATASET"}, "10378.1/1904961": {"model_run/10378.1/1935470": true, "item_category": "ENTITY", "item_subtype": "DATASET"}, "10378.1/1905251": {"model_run/10378.1/1935470": true, "item_category": "ENTITY", "item_subtype": "MODEL_RUN_WORKFLOW_TEMPLATE", "prov:type": {"$": "prov:Collection", "type": "prov:QUALIFIED_NAME"}}, "10378.1/1905250": {"model_run/10378.1/1935470": true, "item_category": "ENTITY", "item_subtype": "DATASET_TEMPLATE"}, "10378.1/1926245": {"model_run/10378.1/1935470": true, "item_category": "ENTITY", "item_subtype": "DATASET_TEMPLA ...
# {'new_version_number': 2, 'owner_username': 'adria-bot', 'from_item_id': '10378.1/1934449', 'updated_timestamp': 1721804024, 'item_category': 'ACTIVITY', 'reason': 'New ADRIA code release on GitHub. Version Unknown.', 'to_item_id': '10378.1/1934463', 'display_name': '(V2) Version from 10378.1/1934449 to 10378.1/1934463', 'history': [{'reason': 'Initial record creation', 'item': {'reason': 'New ADRIA code release on GitHub. Version Unknown.', 'display_name': '(V2) Version from 10378.1/1934449 to 10378.1/1934463', 'to_item_id': '10378.1/1934463', 'from_item_id': '10378.1/1934449', 'new_version_number': 2}, 'id': 0, 'timestamp': 1721804024, 'username': 'adria-bot'}], 'item_subtype': 'VERSION', 'created_timestamp': 1721804024, 'id': '10378.1/1934464', 'record_type': 'COMPLETE_ITEM'}
# {'versioning_info': {'previous_version': '10378.1/1934449', 'version': 2, 'reason': 'New ADRIA code release on GitHub. Version Unknown.'}, 'owner_username': 'adria-bot', 'workflow_links': {'version_activity_workflow_id': 'a1ca2892-a50e-49e7-8c75-88d88f31afaf'}, 'source_url': 'https://github.com/open-AIMS/ADRIA.jl', 'updated_timestamp': 1721804016, 'item_category': 'ENTITY', 'user_metadata': {'git_release': '', 'git_branch': 'provena-update', 'git_hash': 'e1cba08dddafc9df47523676b43869beceb6c68f'}, 'name': 'ADRIA (Test)', 'display_name': 'ADRIA (Test)', 'documentation_url': 'https://github.com/open-AIMS/ADRIA.jl', 'history': [{'reason': 'Updating metadata attributes to specify new git hash, branch and release if available.', 'item': {'name': 'ADRIA (Test)', 'description': 'ADRIA (Test) for testing GitHub integration.', 'user_metadata': {'git_release': '', 'git_branch': 'provena-update', 'git_hash': 'e1cba08dddafc9df47523676b43869beceb6c68f'}, 'display_name': 'ADRIA (Test)', 'documentation_url': 'https://github.com/open-AIMS/ADRIA.jl', 'source_url': 'https://github.com/open-AIMS/ADRIA.jl'}, 'id': 1, 'timestamp': 1721804016, 'username': 'adria-bot'}, {'reason': 'New version of existing item (id=10378.1/1934449).', 'item': {'name': 'ADRIA (Test)', 'description': 'ADRIA (Test) for testing GitHub integration.', 'display_name': 'ADRIA (Test)', 'documentation_url': 'https://github.com/open-AIMS/ADRIA.jl', 'source_url': 'https://github.com/open-AIMS/ADRIA.jl'}, 'id': 0, 'timestamp': 1721804007, 'username': 'adria-bot'}], 'item_subtype': 'MODEL', 'created_timestamp': 1721804007, 'description': 'ADRIA (Test) for testing GitHub integration.', 'id': '10378.1/1934463', 'record_type': 'COMPLETE_ITEM'}
# {'new_version_number': 18, 'owner_username': 'peter', 'from_item_id': '10378.1/1932118', 'updated_timestamp': 1721803929, 'item_category': 'ACTIVITY', 'reason': 'Testing GitHub Action which can version and update items', 'to_item_id': '10378.1/1934461', 'display_name': '(V18) Version from 10378.1/1932118 to 10378.1/1934461', 'history': [{'reason': 'Initial record creation', 'item': {'reason': 'Testing GitHub Action which can version and update items', 'display_name': '(V18) Version from 10378.1/1932118 to 10378.1/1934461', 'to_item_id': '10378.1/1934461', 'from_item_id': '10378.1/1932118', 'new_version_number': 18}, 'id': 0, 'timestamp': 1721803929, 'username': 'peter'}], 'item_subtype': 'VERSION', 'created_timestamp': 1721803929, 'id': '10378.1/1934462', 'record_type': 'COMPLETE_ITEM'}
# {'versioning_info': {'previous_version': '10378.1/1932118', 'version': 18, 'reason': 'Testing GitHub Action which can version and update items'}, 'owner_username': 'peter', 'workflow_links': {'version_activity_workflow_id': '0954d3b8-78be-4f35-aa7d-6ab0ba25cb0d'}, 'source_url': 'https://github.com/provena/version-update-item-action', 'updated_timestamp': 1721803870, 'item_category': 'ENTITY', 'user_metadata': {'git_release': '', 'git_branch': 'main', 'git_hash': '0175e71573a8bd5455f29ac233c0fa083da79c02'}, 'name': 'Github Actions Test Model', 'display_name': 'Github Actions Test Model', 'documentation_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'history': [{'reason': 'Updating git custom attributes, as well as source URL.', 'item': {'name': 'Github Actions Test Model', 'description': 'Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', 'user_metadata': {'git_release': '', 'git_branch': 'main', 'git_hash': '0175e71573a8bd5455f29ac233c0fa083da79c02'}, 'display_name': 'Github Actions Test Model', 'documentation_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'source_url': 'https://github.com/provena/version-update-item-action'}, 'id': 1, 'timestamp': 1721803870, 'username': 'peter'}, {'reason': 'New version of existing item (id=10378.1/1932118).', 'item': {'name': 'Github Actions Test Model', 'description': 'Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', 'user_metadata': {'git_release': 'v0.1.3', 'git_branch': 'v0.1.3', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'}, 'display_name': 'Github Actions Test Model', 'documentation_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'source_url': 'https://github.com/provena/version-update-item-action'}, 'id': 0, 'timestamp': 1721803862, 'username': 'peter'}], 'item_subtype': 'MODEL', 'created_timestamp': 1721803862, 'description': 'Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', 'id': '10378.1/1934461', 'record_type': 'COMPLETE_ITEM'}
# {'history': [{'reason': 'Initial record creation', 'item': {'display_name': 'Created item 10378.1/1934449', 'created_item_id': '10378.1/1934449'}, 'id': 0, 'timestamp': 1721802376, 'username': 'adria-bot'}], 'owner_username': 'adria-bot', 'item_subtype': 'CREATE', 'created_item_id': '10378.1/1934449', 'updated_timestamp': 1721802376, 'created_timestamp': 1721802376, 'item_category': 'ACTIVITY', 'id': '10378.1/1934450', 'display_name': 'Created item 10378.1/1934449', 'record_type': 'COMPLETE_ITEM'}
# {'versioning_info': {'version': 1, 'next_version': '10378.1/1934463'}, 'owner_username': 'adria-bot', 'workflow_links': {'create_activity_workflow_id': '38b91eef-f8a2-40f9-be76-2f8580577971'}, 'source_url': 'https://github.com/open-AIMS/ADRIA.jl', 'updated_timestamp': 1721802318, 'item_category': 'ENTITY', 'name': 'ADRIA (Test)', 'display_name': 'ADRIA (Test)', 'documentation_url': 'https://github.com/open-AIMS/ADRIA.jl', 'history': [{'reason': 'Initial record creation', 'item': {'name': 'ADRIA (Test)', 'description': 'ADRIA (Test) for testing GitHub integration.', 'display_name': 'ADRIA (Test)', 'documentation_url': 'https://github.com/open-AIMS/ADRIA.jl', 'source_url': 'https://github.com/open-AIMS/ADRIA.jl'}, 'id': 0, 'timestamp': 1721802318, 'username': 'adria-bot'}], 'item_subtype': 'MODEL', 'created_timestamp': 1721802318, 'description': 'ADRIA (Test) for testing GitHub integration.', 'id': '10378.1/1934449', 'record_type': 'COMPLETE_ITEM'}
# {'owner_username': 'adria-bot', 'ethics_approved': True, 'updated_timestamp': 1721802265, 'item_category': 'AGENT', 'email': 'adriabot@gmail.com', 'display_name': 'ADRIA Bot', 'history': [{'reason': 'Initial record creation', 'item': {'last_name': 'Bot', 'display_name': 'ADRIA Bot', 'first_name': 'ADRIA', 'email': 'adriabot@gmail.com', 'ethics_approved': True}, 'id': 0, 'timestamp': 1721802265, 'username': 'adria-bot'}], 'item_subtype': 'PERSON', 'last_name': 'Bot', 'first_name': 'ADRIA', 'created_timestamp': 1721802265, 'id': '10378.1/1934448', 'record_type': 'COMPLETE_ITEM'}
# {'s3': {'path': 'datasets/10378-1-1932274/', 's3_uri': 's3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1932274/', 'bucket_name': 'restored-dev-dev-rrap-storage-bucket-11102022-11102022'}, 'versioning_info': {'version': 1}, 'release_history': [], 'owner_username': 'ross', 'workflow_links': {'create_activity_workflow_id': 'c63a85e0-f3f9-4b50-8279-363bab6dc42d'}, 'release_status': 'NOT_RELEASED', 'updated_timestamp': 1721714647, 'item_category': 'ENTITY', 'display_name': 'test', 'collection_format': {'associations': {'organisation_id': '10378.1/1925605'}, 'dataset_info': {'publisher_id': '10378.1/1925605', 'license': 'https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', 'name': 'test', 'description': 'tyest', 'access_info': {'reposited': True}, 'created_date': {'relevant': True, 'value': '2024-08-09'}, 'published_date': {'relevant': False}}, 'approvals': {'ethics_registration': {'relevant': False, 'obtained': False}, 'indigenous_knowledge': {'relevant': False, 'obtained': False}, 'export_controls': {'relevant': False, 'obtained': False}, 'ethics_access': {'relevant': False, 'obtained': False}}}, 'history': [{'reason': 'nmvb ', 'item': {'s3': {'path': 'datasets/10378-1-1932274/', 's3_uri': 's3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1932274/', 'bucket_name': 'restored-dev-dev-rrap-storage-bucket-11102022-11102022'}, 'release_history': [], 'display_name': 'test', 'collection_format': {'associations': {'organisation_id': '10378.1/1925605'}, 'dataset_info': {'publisher_id': '10378.1/1925605', 'license': 'https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', 'name': 'test', 'description': 'tyest', 'access_info': {'reposited': True}, 'created_date': {'relevant': True, 'value': '2024-08-09'}, 'published_date': {'relevant': False}}, 'approvals': {'ethics_registration': {'relevant': False, 'obtained': False}, 'indigenous_knowledge': {'relevant': False, 'obtained': False}, 'export_controls': {'relevant': False, 'obtained': False}, 'ethics_access': {'relevant': False, 'obtained': False}}}, 'release_status': 'NOT_RELEASED'}, 'id': 1, 'timestamp': 1721714647, 'username': 'ross'}, {'reason': 'Initial record creation', 'item': {'s3': {'path': 'datasets/10378-1-1932274/', 's3_uri': 's3://restored-dev-dev-rrap-storage-bucket-11102022-11102022/datasets/10378-1-1932274/', 'bucket_name': 'restored-dev-dev-rrap-storage-bucket-11102022-11102022'}, 'release_history': [], 'display_name': 'test', 'collection_format': {'associations': {'organisation_id': '10378.1/1925605'}, 'dataset_info': {'publisher_id': '10378.1/1925605', 'license': 'https://gbrrestoration.github.io/rrap-mds-knowledge-hub/information-system/licenses.html#copyright-all-rights-reserved-', 'name': 'test', 'description': 'tyest', 'access_info': {'reposited': True}, 'created_date': {'relevant': True, 'value': '2024-08-09'}, 'published_date': {'relevant': True, 'value': '2024-09-20'}}, 'approvals': {'ethics_registration': {'relevant': False, 'obtained': False}, 'indigenous_knowledge': {'relevant': False, 'obtained': False}, 'export_controls': {'relevant': False, 'obtained': False}, 'ethics_access': {'relevant': False, 'obtained': False}}}, 'release_status': 'NOT_RELEASED'}, 'id': 0, 'timestamp': 1721629472, 'username': 'ross'}], 'item_subtype': 'DATASET', 'created_timestamp': 1721629472, 'id': '10378.1/1932274', 'record_type': 'COMPLETE_ITEM'}
# {'history': [{'reason': 'Initial record creation', 'item': {'display_name': 'Created item 10378.1/1932274', 'created_item_id': '10378.1/1932274'}, 'id': 0, 'timestamp': 1721629527, 'username': 'ross'}], 'owner_username': 'ross', 'item_subtype': 'CREATE', 'created_item_id': '10378.1/1932274', 'updated_timestamp': 1721629527, 'created_timestamp': 1721629527, 'item_category': 'ACTIVITY', 'id': '10378.1/1932275', 'display_name': 'Created item 10378.1/1932274', 'record_type': 'COMPLETE_ITEM'}
# {'owner_username': 'fareed', 'ethics_approved': True, 'updated_timestamp': 1721610549, 'item_category': 'AGENT', 'email': 'fareed.mirza@csiro.au', 'display_name': 'Fareed Mirza', 'history': [{'reason': 'Initial record creation', 'item': {'last_name': 'Mirza', 'display_name': 'Fareed Mirza', 'first_name': 'Fareed', 'email': 'fareed.mirza@csiro.au', 'ethics_approved': True}, 'id': 0, 'timestamp': 1721610549, 'username': 'fareed'}], 'item_subtype': 'PERSON', 'last_name': 'Mirza', 'first_name': 'Fareed', 'created_timestamp': 1721610549, 'id': '10378.1/1932158', 'record_type': 'COMPLETE_ITEM'}
# {'new_version_number': 17, 'owner_username': 'peter', 'from_item_id': '10378.1/1932116', 'updated_timestamp': 1721605316, 'item_category': 'ACTIVITY', 'reason': 'Testing GitHub Action which can version and update items', 'to_item_id': '10378.1/1932118', 'display_name': '(V17) Version from 10378.1/1932116 to 10378.1/1932118', 'history': [{'reason': 'Initial record creation', 'item': {'reason': 'Testing GitHub Action which can version and update items', 'display_name': '(V17) Version from 10378.1/1932116 to 10378.1/1932118', 'to_item_id': '10378.1/1932118', 'from_item_id': '10378.1/1932116', 'new_version_number': 17}, 'id': 0, 'timestamp': 1721605316, 'username': 'peter'}], 'item_subtype': 'VERSION', 'created_timestamp': 1721605316, 'id': '10378.1/1932119', 'record_type': 'COMPLETE_ITEM'}
# {'versioning_info': {'reason': 'Testing GitHub Action which can version and update items', 'previous_version': '10378.1/1932116', 'version': 17, 'next_version': '10378.1/1934461'}, 'owner_username': 'peter', 'workflow_links': {'version_activity_workflow_id': '7659941a-2bac-4750-9576-faf50a592deb'}, 'source_url': 'https://github.com/provena/version-update-item-action', 'updated_timestamp': 1721605309, 'item_category': 'ENTITY', 'user_metadata': {'git_release': 'v0.1.3', 'git_branch': 'v0.1.3', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'}, 'name': 'Github Actions Test Model', 'display_name': 'Github Actions Test Model', 'documentation_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'history': [{'reason': 'Updating git custom attributes, as well as source URL.', 'item': {'name': 'Github Actions Test Model', 'description': 'Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', 'user_metadata': {'git_release': 'v0.1.3', 'git_branch': 'v0.1.3', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'}, 'display_name': 'Github Actions Test Model', 'documentation_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'source_url': 'https://github.com/provena/version-update-item-action'}, 'id': 1, 'timestamp': 1721605309, 'username': 'peter'}, {'reason': 'New version of existing item (id=10378.1/1932116).', 'item': {'name': 'Github Actions Test Model', 'description': 'Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', 'user_metadata': {'git_release': 'v0.1.3', 'git_branch': 'v0.1.3', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'}, 'display_name': 'Github Actions Test Model', 'documentation_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'source_url': 'https://github.com/provena/version-update-item-action'}, 'id': 0, 'timestamp': 1721605300, 'username': 'peter'}], 'item_subtype': 'MODEL', 'created_timestamp': 1721605300, 'description': 'Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', 'id': '10378.1/1932118', 'record_type': 'COMPLETE_ITEM'}
# {'new_version_number': 16, 'owner_username': 'peter', 'from_item_id': '10378.1/1932114', 'updated_timestamp': 1721605249, 'item_category': 'ACTIVITY', 'reason': 'Testing GitHub Action which can version and update items', 'to_item_id': '10378.1/1932116', 'display_name': '(V16) Version from 10378.1/1932114 to 10378.1/1932116', 'history': [{'reason': 'Initial record creation', 'item': {'reason': 'Testing GitHub Action which can version and update items', 'display_name': '(V16) Version from 10378.1/1932114 to 10378.1/1932116', 'to_item_id': '10378.1/1932116', 'from_item_id': '10378.1/1932114', 'new_version_number': 16}, 'id': 0, 'timestamp': 1721605249, 'username': 'peter'}], 'item_subtype': 'VERSION', 'created_timestamp': 1721605249, 'id': '10378.1/1932117', 'record_type': 'COMPLETE_ITEM'}
# {'versioning_info': {'reason': 'Testing GitHub Action which can version and update items', 'previous_version': '10378.1/1932114', 'version': 16, 'next_version': '10378.1/1932118'}, 'owner_username': 'peter', 'workflow_links': {'version_activity_workflow_id': '49577042-9d2b-4677-ae06-9afb061d326c'}, 'source_url': 'https://github.com/provena/version-update-item-action', 'updated_timestamp': 1721605241, 'item_category': 'ENTITY', 'user_metadata': {'git_release': 'v0.1.3', 'git_branch': 'v0.1.3', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'}, 'name': 'Github Actions Test Model', 'display_name': 'Github Actions Test Model', 'documentation_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'history': [{'reason': 'Updating git custom attributes, as well as source URL.', 'item': {'name': 'Github Actions Test Model', 'description': 'Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', 'user_metadata': {'git_release': 'v0.1.3', 'git_branch': 'v0.1.3', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'}, 'display_name': 'Github Actions Test Model', 'documentation_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'source_url': 'https://github.com/provena/version-update-item-action'}, 'id': 1, 'timestamp': 1721605241, 'username': 'peter'}, {'reason': 'New version of existing item (id=10378.1/1932114).', 'item': {'name': 'Github Actions Test Model', 'description': 'Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', 'user_metadata': {'git_release': '', 'git_branch': 'main', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'}, 'display_name': 'Github Actions Test Model', 'documentation_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'source_url': 'https://github.com/provena/version-update-item-action'}, 'id': 0, 'timestamp': 1721605232, 'username': 'peter'}], 'item_subtype': 'MODEL', 'created_timestamp': 1721605232, 'description': 'Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', 'id': '10378.1/1932116', 'record_type': 'COMPLETE_ITEM'}
# {'new_version_number': 15, 'owner_username': 'peter', 'from_item_id': '10378.1/1932112', 'updated_timestamp': 1721605225, 'item_category': 'ACTIVITY', 'reason': 'Testing GitHub Action which can version and update items', 'to_item_id': '10378.1/1932114', 'display_name': '(V15) Version from 10378.1/1932112 to 10378.1/1932114', 'history': [{'reason': 'Initial record creation', 'item': {'reason': 'Testing GitHub Action which can version and update items', 'display_name': '(V15) Version from 10378.1/1932112 to 10378.1/1932114', 'to_item_id': '10378.1/1932114', 'from_item_id': '10378.1/1932112', 'new_version_number': 15}, 'id': 0, 'timestamp': 1721605225, 'username': 'peter'}], 'item_subtype': 'VERSION', 'created_timestamp': 1721605225, 'id': '10378.1/1932115', 'record_type': 'COMPLETE_ITEM'}
# {'versioning_info': {'reason': 'Testing GitHub Action which can version and update items', 'previous_version': '10378.1/1932112', 'version': 15, 'next_version': '10378.1/1932116'}, 'owner_username': 'peter', 'workflow_links': {'version_activity_workflow_id': '41d4dc0d-0bf1-4153-879c-ba58dda44f51'}, 'source_url': 'https://github.com/provena/version-update-item-action', 'updated_timestamp': 1721605218, 'item_category': 'ENTITY', 'user_metadata': {'git_release': '', 'git_branch': 'main', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'}, 'name': 'Github Actions Test Model', 'display_name': 'Github Actions Test Model', 'documentation_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'history': [{'reason': 'Updating git custom attributes, as well as source URL.', 'item': {'name': 'Github Actions Test Model', 'description': 'Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', 'user_metadata': {'git_release': '', 'git_branch': 'main', 'git_hash': 'd91788f041b28f3d8802b5854005bb6d601efaf6'}, 'display_name': 'Github Actions Test Model', 'documentation_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'source_url': 'https://github.com/provena/version-update-item-action'}, 'id': 1, 'timestamp': 1721605218, 'username': 'peter'}, {'reason': 'New version of existing item (id=10378.1/1932112).', 'item': {'name': 'Github Actions Test Model', 'description': 'Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', 'user_metadata': {'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}, 'display_name': 'Github Actions Test Model', 'documentation_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'source_url': 'https://github.com/PeterBaker0/update-provena-model-action'}, 'id': 0, 'timestamp': 1721605209, 'username': 'peter'}], 'item_subtype': 'MODEL', 'created_timestamp': 1721605209, 'description': 'Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', 'id': '10378.1/1932114', 'record_type': 'COMPLETE_ITEM'}
# {'new_version_number': 14, 'owner_username': 'peter', 'from_item_id': '10378.1/1932110', 'updated_timestamp': 1721605119, 'item_category': 'ACTIVITY', 'reason': 'Testing GitHub Action which can version and update items', 'to_item_id': '10378.1/1932112', 'display_name': '(V14) Version from 10378.1/1932110 to 10378.1/1932112', 'history': [{'reason': 'Initial record creation', 'item': {'reason': 'Testing GitHub Action which can version and update items', 'display_name': '(V14) Version from 10378.1/1932110 to 10378.1/1932112', 'to_item_id': '10378.1/1932112', 'from_item_id': '10378.1/1932110', 'new_version_number': 14}, 'id': 0, 'timestamp': 1721605119, 'username': 'peter'}], 'item_subtype': 'VERSION', 'created_timestamp': 1721605119, 'id': '10378.1/1932113', 'record_type': 'COMPLETE_ITEM'}
# {'versioning_info': {'reason': 'Testing GitHub Action which can version and update items', 'previous_version': '10378.1/1932110', 'version': 14, 'next_version': '10378.1/1932114'}, 'owner_username': 'peter', 'workflow_links': {'version_activity_workflow_id': 'b602fbdc-7aea-48ad-9ccc-a078c34f06dd'}, 'source_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'updated_timestamp': 1721605111, 'item_category': 'ENTITY', 'user_metadata': {'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}, 'name': 'Github Actions Test Model', 'display_name': 'Github Actions Test Model', 'documentation_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'history': [{'reason': 'Updating git custom attributes, as well as source URL.', 'item': {'name': 'Github Actions Test Model', 'description': 'Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', 'user_metadata': {'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}, 'display_name': 'Github Actions Test Model', 'documentation_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'source_url': 'https://github.com/PeterBaker0/update-provena-model-action'}, 'id': 1, 'timestamp': 1721605111, 'username': 'peter'}, {'reason': 'New version of existing item (id=10378.1/1932110).', 'item': {'name': 'Github Actions Test Model', 'description': 'Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', 'user_metadata': {'git_release': 'None', 'git_branch': 'None', 'git_hash': 'None'}, 'display_name': 'Github Actions Test Model', 'documentation_url': 'https://github.com/PeterBaker0/update-provena-model-action', 'source_url': 'https://github.com/PeterBaker0/update-provena-model-action'}, 'id': 0, 'timestamp': 1721605102, 'username': 'peter'}], 'item_subtype': 'MODEL', 'created_timestamp': 1721605102, 'description': 'Github Actions Test Model \n\nThis will be automatically managed as part of validating the CI/CD workflow.', 'id': '10378.1/1932112', 'record_type': 'COMPLETE_ITEM'}
# {'new_version_number': 13, 'owner_username': 'peter', 'from_item_id': '10378.1/1932076', 'updated_timestamp': 1721605105, 'item_category': 'ACTIVITY', 'reason': 'Testing GitHub Action which can version and update items', 'to_item_id': '10378.1/1932110', 'display_name': '(V13) Version from 10378.1/1932076 to 10378.1/1932110', 'history': [{'reason': 'Initial record creation', 'item': {'reason': 'Testing GitHub Action which can version and update items', 'display_name': '(V13) Version from 10378.1/1932076 to 10378.1/1932110', 'to_item_id': '10378.1/1932110', 'from_item_id': '10378.1/1932076', 'new_version_number': 13}, 'id': 0, 'timestamp': 1721605105, 'username': 'peter'}], 'item_subtype': 'VERSION', 'created_timestamp': 1721605105, 'id': '10378.1/1932111', 'record_type': 'COMPLETE_ITEM'}

# %%
# Count of all items based on subtypes. 
count_of_all_items = await client.registry.list_registry_items_with_count()
print(count_of_all_items)
# Out:
# {'MODEL_RUN': 112, 'VERSION': 21, 'MODEL': 26, 'CREATE': 258, 'PERSON': 29, 'DATASET': 210, 'MODEL_RUN_WORKFLOW_TEMPLATE': 7, 'DATASET_TEMPLATE': 14, 'ORGANISATION': 17, 'STUDY': 4}
